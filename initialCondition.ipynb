# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Re_tau = 295
yPlus = np.linspace(0, Re_tau, Re_tau+1)
nu = 1e-6
delta = 2e-3
u_tau = Re_tau*nu/delta

# %%
uu = 1 + 1.5*yPlus*np.exp(-yPlus/12)
ww = 1 + 0.1*yPlus*np.exp(-yPlus/26)

plt.figure()
plt.plot(uu)
plt.plot(ww)
plt.xlim(1, Re_tau)
plt.ylim(0, 8)
# plt.xscale("log")
plt.grid()
plt.show()
